# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:\\Users\\admin\\Downloads\\ifood_df.csv")

data.head()
# Out:
#     Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0  58138.0        0         0       58       635         88              546
# 1  46344.0        1         1       38        11          1                6
# 2  71613.0        0         0       26       426         49              127
# 3  26646.0        1         0       26        11          4               20
# 4  58293.0        1         0       94       173         43              118
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  ...  marital_Together  \
# 0              172                88            88  ...                 0
# 1                2                 1             6  ...                 0
# 2              111                21            42  ...                 1
# 3               10                 3             5  ...                 1
# 4               46                27            15  ...                 0
#
# ...

# %%
data.isna().sum()
# Out:
# Income                  0
# Kidhome                 0
# Teenhome                0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# Age                     0
# Customer_Days           0
# marital_Divorced        0
# marital_Married         0
# marital_Single          0
# marital_Together        0
# marital_Widow           0
# education_2n Cycle      0
# education_Basic         0
# education_Graduation    0
# education_Master        0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2205 entries, 0 to 2204
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Income                2205 non-null   float64
#  1   Kidhome               2205 non-null   int64
#  2   Teenhome              2205 non-null   int64
#  3   Recency               2205 non-null   int64
#  4   MntWines              2205 non-null   int64
#  5   MntFruits             2205 non-null   int64
#  6   MntMeatProducts       2205 non-null   int64
#  7   MntFishProducts       2205 non-null   int64
#  8   MntSweetProducts      2205 non-null   int64
#  9   MntGoldProds          2205 non-null   int64
#  10  NumDealsPurchases     2205 non-null   int64
#  11  NumWebPurchases       2205 non-null   int64
#  12  NumCatalogPurchases   2205 non-null   int64
#  13  NumStorePurchases     2205 non-null   int64
#  14  NumWebVisitsMonth     2205 non-null   int64
# ...

# %%
data.nunique()
# Out:
# Income                  1963
# Kidhome                    3
# Teenhome                   3
# Recency                  100
# MntWines                 775
# MntFruits                158
# MntMeatProducts          551
# MntFishProducts          182
# MntSweetProducts         176
# MntGoldProds             212
# NumDealsPurchases         15
# NumWebPurchases           15
# NumCatalogPurchases       13
# NumStorePurchases         14
# NumWebVisitsMonth         16
# AcceptedCmp3               2
# AcceptedCmp4               2
# AcceptedCmp5               2
# AcceptedCmp1               2
# AcceptedCmp2               2
# Complain                   2
# Z_CostContact              1
# Z_Revenue                  1
# Response                   2
# Age                       56
# Customer_Days            662
# marital_Divorced           2
# marital_Married            2
# marital_Single             2
# marital_Together           2
# marital_Widow              2
# education_2n Cycle         2
# ...

# %%
data.drop(columns=['Z_CostContact', 'Z_Revenue'], inplace=True, errors='ignore')

# %%
data.describe()
# Out:
#               Income      Kidhome     Teenhome      Recency     MntWines  \
# count    2205.000000  2205.000000  2205.000000  2205.000000  2205.000000
# mean    51622.094785     0.442177     0.506576    49.009070   306.164626
# std     20713.063826     0.537132     0.544380    28.932111   337.493839
# min      1730.000000     0.000000     0.000000     0.000000     0.000000
# 25%     35196.000000     0.000000     0.000000    24.000000    24.000000
# 50%     51287.000000     0.000000     0.000000    49.000000   178.000000
# 75%     68281.000000     1.000000     1.000000    74.000000   507.000000
# max    113734.000000     2.000000     2.000000    99.000000  1493.000000
#
#          MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# count  2205.000000      2205.000000      2205.000000       2205.000000
# mean     26.403175       165.312018        37.756463         27.128345
# std      39.784484       217.784507        54.824635         41.130468
# ...

# %%
data.mode().dropna()
# Out:
#    Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0  7500.0      0.0       0.0     56.0       2.0        0.0              7.0
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  ...  marital_Together  \
# 0              0.0               0.0             3  ...               0.0
#
#    marital_Widow  education_2n Cycle  education_Basic  education_Graduation  \
# 0            0.0                 0.0              0.0                   1.0
#
#    education_Master  education_PhD  MntTotal  MntRegularProds  \
# 0               0.0            0.0      39.0               16
#
#    AcceptedCmpOverall
# 0                 0.0
#
# [1 rows x 37 columns]

# %%
def get_relationship(row):
    if 'marital_married' in row and row['marital_married'] == 1:
        return 1
    elif 'marital_Together' in row and row['marital_Together'] == 1:
        return 1
    else:
        return 0

# %%
data['In_relationship'] = data.apply(get_relationship, axis=1)
data.head()
# Out:
#     Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0  58138.0        0         0       58       635         88              546
# 1  46344.0        1         1       38        11          1                6
# 2  71613.0        0         0       26       426         49              127
# 3  26646.0        1         0       26        11          4               20
# 4  58293.0        1         0       94       173         43              118
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  ...  marital_Widow  \
# 0              172                88            88  ...              0
# 1                2                 1             6  ...              0
# 2              111                21            42  ...              0
# 3               10                 3             5  ...              0
# 4               46                27            15  ...              0
#
#    education_2n Cycle  education_Basic  education_Graduation  \
# ...

# %%
data.rename(columns={'education_2n Cycle\t': 'education_2n Cycle'}, inplace=True)

# %%
def Education_Status(row):
    if row['education_2n Cycle'] == 1:
        return '2'
    elif row['education_Basic'] == 1:
        return '1'
    elif row['education_Graduation'] == 1:
        return '3'
    elif row['education_Master'] == 1:
        return '4'
    elif row['education_PhD'] == 1:
        return '5'
    else:
        return 'Unknown'

# %%
data['Education_status'] = data.apply(Education_Status, axis=1)

# %%
from sklearn.cluster import KMeans

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
cols_for_clustering = ['Income', 'MntTotal', 'In_relationship','Education_status']
data_scaled = data.copy()
data_scaled[cols_for_clustering] = scaler.fit_transform(data[cols_for_clustering])

# %%
X = data_scaled[cols_for_clustering]
inertia_list = []
for k in range(1,11):
    inertia = KMeans(n_clusters=k , n_init=10).fit(X).inertia_
    inertia_list.append(inertia)

# %%
plt.figure(figsize=[7,5])
plt.plot(range(1,11), inertia_list) 
plt.title("Inertia vs. Number of Clusters")
plt.xlabel("Number of Clusters (K)")
plt.ylabel("Inertia")
plt.show()

# %%
model = KMeans(n_clusters=4, random_state = 7)
model.fit(data_scaled[cols_for_clustering])
data_scaled['Cluster'] = model.predict(data_scaled[cols_for_clustering])

# %%
from sklearn import decomposition
pca= decomposition.PCA(n_components= 2)
pca_res = pca.fit_transform(data_scaled[cols_for_clustering])
data_scaled['pc1']= pca_res[:,0]
data_scaled['pc2']= pca_res[:,1]

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='pc1', y='pc2', data=data_scaled, hue='Cluster', palette='viridis')
plt.title('Clustered Data Visualization')
plt.xlabel('Principal Component 1 (pc1)')
plt.ylabel('Principal Component 2 (pc2)')
plt.legend(title='Clusters')

# %%
customer_num = data_scaled.groupby('Cluster')['MntTotal'].count().reset_index()

plt.figure(figsize=(8, 6))
sns.barplot(x='Cluster', y='MntTotal', data=customer_num, palette='viridis')
plt.title('Cluster sizes')
plt.xlabel('Cluster')
plt.ylabel('customer_num')
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_5508\2294768021.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Cluster', y='MntTotal', data=customer_num, palette='viridis')

# %%
scaler = StandardScaler()
cols_for_clustering = ['Income', 'MntTotal', 'In_relationship','Education_status']
data_clustered = data.copy()

model = KMeans(n_clusters=4, random_state = 7)
model.fit(data_clustered[cols_for_clustering])
data_clustered['Cluster'] = model.predict(data_clustered[cols_for_clustering])
data_clustered.head()
# Out:
#     Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0  58138.0        0         0       58       635         88              546
# 1  46344.0        1         1       38        11          1                6
# 2  71613.0        0         0       26       426         49              127
# 3  26646.0        1         0       26        11          4               20
# 4  58293.0        1         0       94       173         43              118
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  ...  education_Basic  \
# 0              172                88            88  ...                0
# 1                2                 1             6  ...                0
# 2              111                21            42  ...                0
# 3               10                 3             5  ...                0
# 4               46                27            15  ...                0
#
# ...

# %%
data_clustered['Avg_income'] = data_clustered.groupby('Cluster')['Income'].mean()

plt.figure(figsize=(8, 6))
sns.barplot(x='Cluster', y='Avg_income', data=data_clustered, palette='viridis')
plt.title('Cluster Avg_income')
plt.xlabel('Clusters')
plt.ylabel('Avg_income')
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_5508\354923289.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Cluster', y='Avg_income', data=data_clustered, palette='viridis')

# %%
Avg_Consumption = data_clustered.groupby('Cluster')[['MntWines', 'MntFruits', 'MntMeatProducts','MntFishProducts','MntSweetProducts','MntGoldProds','MntTotal']].mean()

# Display the results
print(Avg_Consumption)
# Out:
#            MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# Cluster
# 0        116.895928   7.980392        46.001508        13.214178
# 1         17.118421   5.508772        20.778509         7.975877
# 2        651.705128  63.722222       449.508547        92.391026
# 3        460.820388  33.323625       184.739482        44.686084
#
#          MntSweetProducts  MntGoldProds     MntTotal
# Cluster
# 0                8.196078     27.006033   192.288084
# 1                5.725877     16.217105    57.107456
# 2               68.707265     74.358974  1326.034188
# 3               31.744337     59.944984   755.313916

# %%
# Add a Cluster column with 4 values
Avg_Consumption["Cluster"] = [0, 1, 2, 3]  # Adjusted to match the 4 rows
 # Example clusters

# Melt the DataFrame
melted_data = pd.melt(
    Avg_Consumption, 
    id_vars="Cluster", 
    var_name="Product", 
    value_name="Consumption"
)

# Plot
plt.figure(figsize=(12, 10))
sns.barplot(x="Cluster", y="Consumption", hue="Product", data=melted_data, palette="viridis", errorbar=None)
plt.title("Product Consumption by Cluster")
plt.xlabel("Cluster")
plt.ylabel("Consumption")
plt.xticks(rotation=0)
plt.legend(title="Product", loc="upper right")
plt.show()

# %%
print(Avg_Consumption.columns)
# Out:
# Index(['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts',
#        'MntSweetProducts', 'MntGoldProds', 'MntTotal'],
#       dtype='object')

# %%
print(len(Avg_Consumption))
# Out:
# 4
